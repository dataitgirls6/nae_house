# %%
import pandas as pd
df1 = pd.read_csv('deco_plant.csv')
df1
# Out:
#         id                                                url
# 0        0  https://ohou.se/projects/126917/detail?affect_...
# 1        1  https://ohou.se/projects/126600/detail?affect_...
# 2        2  https://ohou.se/projects/123056/detail?affect_...
# 3        3  https://ohou.se/projects/116945/detail?affect_...
# 4        4  https://ohou.se/projects/127436/detail?affect_...
# ...    ...                                                ...
# 4431  4687  https://ohou.se/projects/19671/detail?affect_t...
# 4432  4688  https://ohou.se/projects/18922/detail?affect_t...
# 4433  4689  https://ohou.se/projects/20141/detail?affect_t...
# 4434  4690  https://ohou.se/projects/20628/detail?affect_t...
# 4435  4691  https://ohou.se/projects/19720/detail?affect_t...
#
# [4436 rows x 2 columns]

# %% [markdown]
# - 김민지 [0:700]
#
# - 박유정 [700:1400]
#
# - 이소현 [1400:2100]
#
# - 이지혜 [2100:2800]
#
# - 최수연 [2800:3500]
#
# - 송나현 [3500:]

# %%
start = 1284
end = 1400

# %%
df1 = df1[start:end]
df1.head(40)
# Out:
#         id                                                url
# 1284  1323  https://ohou.se/projects/78755/detail?affect_t...
# 1285  1324  https://ohou.se/projects/80178/detail?affect_t...
# 1286  1325  https://ohou.se/projects/80912/detail?affect_t...
# 1287  1326  https://ohou.se/projects/80489/detail?affect_t...
# 1288  1327  https://ohou.se/projects/80255/detail?affect_t...
# 1289  1328  https://ohou.se/projects/79065/detail?affect_t...
# 1290  1329  https://ohou.se/projects/77905/detail?affect_t...
# 1291  1330  https://ohou.se/projects/81226/detail?affect_t...
# 1292  1331  https://ohou.se/projects/79141/detail?affect_t...
# 1293  1332  https://ohou.se/projects/78031/detail?affect_t...
# 1294  1333  https://ohou.se/projects/77808/detail?affect_t...
# 1295  1334  https://ohou.se/projects/76204/detail?affect_t...
# 1296  1335  https://ohou.se/projects/79459/detail?affect_t...
# 1297  1336  https://ohou.se/projects/79454/detail?affect_t...
# 1298  1337  https://ohou.se/projects/77973/detail?affect_t...
# 1299  1338  https://ohou.se/projects/78434/detail?affect_t...
# 1300  1339  https://ohou.se/projects/79005/detail?affect_t...
# 1301  1340  https://ohou.se/projects/79668/detail?affect_t...
# 1302  1341  https://ohou.se/projects/79232/detail?affect_t...
# 1303  1342  https://ohou.se/projects/78624/detail?affect_t...
# 1304  1343  https://ohou.se/projects/78925/detail?affect_t...
# 1305  1344  https://ohou.se/projects/75920/detail?affect_t...
# 1306  1345  https://ohou.se/projects/79061/detail?affect_t...
# 1307  1346  https://ohou.se/projects/77817/detail?affect_t...
# 1308  1347  https://ohou.se/projects/78797/detail?affect_t...
# 1309  1348  https://ohou.se/projects/78628/detail?affect_t...
# 1310  1349  https://ohou.se/projects/78712/detail?affect_t...
# 1311  1351  https://ohou.se/projects/78401/detail?affect_t...
# 1312  1352  https://ohou.se/projects/79520/detail?affect_t...
# 1313  1353  https://ohou.se/projects/78706/detail?affect_t...
# 1314  1354  https://ohou.se/projects/78311/detail?affect_t...
# 1315  1355  https://ohou.se/projects/78550/detail?affect_t...
# 1316  1356  https://ohou.se/projects/78830/detail?affect_t...
# 1317  1357  https://ohou.se/projects/77664/detail?affect_t...
# 1318  1358  https://ohou.se/projects/76433/detail?affect_t...
# 1319  1359  https://ohou.se/projects/79453/detail?affect_t...
# 1320  1360  https://ohou.se/projects/78611/detail?affect_t...
# 1321  1361  https://ohou.se/projects/78275/detail?affect_t...
# 1322  1362  https://ohou.se/projects/77546/detail?affect_t...
# 1323  1363  https://ohou.se/projects/75267/detail?affect_t...

# %%
df_similar = pd.DataFrame(columns = ['id', 'url', 'photo_id', '상품url'])

# %%
# 클릭할 영역 찾기
def find_area_and_elements(xpath, class_name):
    clickable_list = driver.find_element(By.XPATH, xpath)
    # 일단 해당 영역으로 마우스(커서)를 이동시킴
    action = webdriver.ActionChains(driver)
    action.move_to_element(clickable_list).perform()

    items = clickable_list.find_elements(By.CLASS_NAME, 'css-1nqec2d')
    return items

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as BS
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By # import 문 추가
import pandas as pd
import warnings

warnings.filterwarnings(action='ignore')

chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
# 페이지가 모두 로드될 때까지 10초 기다려주도록 처리 (암시적)
driver.implicitly_wait(10)

for idx in df1.index:
    url = df1['url'].loc[idx]
    driver.get(url)

    html = driver.page_source
    soup = BS(html, 'html.parser')
    contents = soup.find_all(['a', 'div'], ['project-detail-image-block__link', 'bpd-view-heading-block'])

    for i, content in enumerate(contents):
        try:
            text = content.text
        except:
            continue
        else:
            if '3초' in text:
                break


    for a_tag in contents[i + 1:]:
        try:
            link = a_tag.attrs['href']
        except:
            break
        else:
            driver.get('https://ohou.se' + link)
            xpath = '/html/body/div[1]/div/div/div[2]/div[1]/div/div[2]/div[2]'
            class_name = 'css-1nqec2d'
            items = find_area_and_elements(xpath, class_name)
            for i in range(0, len(items)):
                if i == 7:
                    break
                items[i].click()
                prd_url = driver.current_url
                
                add_row = pd.DataFrame([{'id' : df1['id'].loc[idx], 
                                         'url' : url,
                                         'photo_id' : link.split('/')[-1],
                                         '상품url' : prd_url}])
                df_similar = df_similar.append(add_row)
                
                driver.back()
                items = find_area_and_elements(xpath, class_name)
    
    if (idx + 1) % 10 == 0:
        df_similar.to_csv(f'df_similar_{start}_{idx}.csv', index = False)
        print(idx)


driver.close()

df_similar.to_csv(f'df_similar_{start}_{end}.csv', index = False)
# Out:
# 1289
# 1299
# 1309
# 1319
# 1329
# 1339

# %%
df_similar.to_csv(f'df_similar_{start}_{idx}.csv', index = False)
print(idx)

# %% [markdown]
# #####
